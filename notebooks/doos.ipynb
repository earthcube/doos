# %% [markdown]
# # Query test notebook

# %%
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
def sparql_to_dataframe(endpoint: str, query: str) -> pd.DataFrame:
    """
    Execute a SPARQL query against an endpoint and return results as a DataFrame.
    
    Args:
        endpoint: SPARQL endpoint URL
        query: SPARQL query string
        
    Returns:
        DataFrame with SPARQL variables as column headers
    """
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)

    results = sparql.query().convert()

    columns = results["head"]["vars"]
    rows = []

    for binding in results["results"]["bindings"]:
        row = {var: binding.get(var, {}).get("value", None) for var in columns}
        rows.append(row)

    return pd.DataFrame(rows, columns=columns)

# %%
# Load SPARQL query from file and execute
with open('../SPARQL/yl1.rq', 'r') as f:
    query = f.read()

endpoint = 'https://qlever.geocodes-aws-dev.earthcube.org/graphspace/deepoceans'
df = sparql_to_dataframe(endpoint, query)
print(df)
# Out:
#                                                      g  \
# 0    urn:gleaner.io:eco:bodc:data:dcc31369dbbf9241f...
# 1    urn:gleaner.io:eco:bodc:data:667beccb0034ef8e3...
# 2    urn:gleaner.io:eco:bodc:data:3b2b639aa2e1d97ca...
# 3    urn:gleaner.io:eco:bodc:data:84110aa3b55c724c9...
# 4    urn:gleaner.io:eco:bodc:data:b84af54db7068b2d2...
# ..                                                 ...
# 495  urn:gleaner.io:eco:bodc:data:27f58136e8e2343ab...
# 496  urn:gleaner.io:eco:bodc:data:76bbde0e11cecdc57...
# 497  urn:gleaner.io:eco:bodc:data:98daafeaa8111157f...
# 498  urn:gleaner.io:eco:bodc:data:68e9b90c75c99a517...
# 499  urn:gleaner.io:eco:bodc:data:b891b1bdb3bbeed53...
#
#                                                   subj  \
# 0    https://api.linked-systems.uk/api/schema-org/d...
# 1    https://api.linked-systems.uk/api/schema-org/d...
# 2    https://api.linked-systems.uk/api/schema-org/d...
# 3    https://api.linked-systems.uk/api/schema-org/d...
# 4    https://api.linked-systems.uk/api/schema-org/d...
# ..                                                 ...
# 495  https://api.linked-systems.uk/api/schema-org/d...
# 496  https://api.linked-systems.uk/api/schema-org/d...
# 497  https://api.linked-systems.uk/api/schema-org/d...
# 498  https://api.linked-systems.uk/api/schema-org/d...
# 499  https://api.linked-systems.uk/api/schema-org/d...
#
#                                                     vm         name minValue  \
# 0    https://gleaner.io/xid/genid/d5htcg0jo11s739mr85g       BinDep       11
# 1    https://gleaner.io/xid/genid/d5htc80jo11s739mn6cg       BinDep       11
# 2    https://gleaner.io/xid/genid/d5htc58jo11s739mlms0       BinDep       11
# 3    https://gleaner.io/xid/genid/d5htc9ojo11s739mo710       BinDep       11
# 4    https://gleaner.io/xid/genid/d5htcd8jo11s739mpu90       BinDep       11
# ..                                                 ...          ...      ...
# 495  https://gleaner.io/xid/genid/d5htc48jo11s739mkvk0  Start_depth     6.94
# 496  https://gleaner.io/xid/genid/d5htc90jo11s739mnom0  Start_depth     6.94
# 497  https://gleaner.io/xid/genid/d5htcb0jo11s739movm0  Start_depth     22.8
# 498  https://gleaner.io/xid/genid/d5htc88jo11s739mn9bg  Start_depth     6.94
# 499  https://gleaner.io/xid/genid/d5htcdgjo11s739mpvig  Start_depth    20.82
#
#     maxValue                                         propertyId unitCode  \
# 0        407  https://vocab.nerc.ac.uk/collection/P01/curren...     None
# 1        407  https://vocab.nerc.ac.uk/collection/P01/curren...     None
# 2        407  https://vocab.nerc.ac.uk/collection/P01/curren...     None
# 3        407  https://vocab.nerc.ac.uk/collection/P01/curren...     None
# 4        407  https://vocab.nerc.ac.uk/collection/P01/curren...     None
# ..       ...                                                ...      ...
# 495   100.12  https://vocab.nerc.ac.uk/collection/P01/curren...     None
# 496  2007.97  https://vocab.nerc.ac.uk/collection/P01/curren...     None
# 497  4829.52  https://vocab.nerc.ac.uk/collection/P01/curren...     None
# 498    102.1  https://vocab.nerc.ac.uk/collection/P01/curren...     None
# 499  4827.58  https://vocab.nerc.ac.uk/collection/P01/curren...     None
#
#     unitText
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# ..       ...
# 495     None
# 496     None
# 497     None
# 498     None
# 499     None
#
# [500 rows x 9 columns]
